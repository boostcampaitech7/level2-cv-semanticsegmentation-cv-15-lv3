# %%
import os
import cv2
import numpy as np
import json
from skimage import filters
from scipy import ndimage

# 입력 및 출력 디렉토리 설정
input_dir = "/data/ephemeral/home/MCG/data/train/DCM"
output_dir = "/data/ephemeral/home/MCG/preProcessing"
label_dir = "/data/ephemeral/home/MCG/data/train/outputs_json"  # 라벨이 있는 디렉토리 경로 설정
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 가장 큰 외곽선 추출 함수
def extract_largest_contour(result_mask, original_image):
    contours, _ = cv2.findContours(result_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        contour_mask = np.zeros_like(result_mask)
        cv2.drawContours(contour_mask, [largest_contour], -1, 255, thickness=cv2.FILLED)
        return cv2.bitwise_and(original_image, original_image, mask=contour_mask)
    return result_mask

# 각 이미지를 처리하여 CLAHE 후 가장 큰 컨투어 추출 결과 저장
def process_image(image_path, output_path, label_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    _, binary = cv2.threshold(gray_image, 45, 255, cv2.THRESH_BINARY)
    kernel = np.ones((8, 8), np.uint8)
    binary = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
    
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    largest_contour = max(contours, key=cv2.contourArea)
    hull = cv2.convexHull(largest_contour)
    
    convex_hull_mask = np.zeros_like(gray_image)
    cv2.drawContours(convex_hull_mask, [hull], -1, 255, thickness=cv2.FILLED)
    image_with_hull = cv2.bitwise_and(image, image, mask=convex_hull_mask)
    
    clahe = cv2.createCLAHE(clipLimit=3.2, tileGridSize=(42, 42))
    enhanced_image = clahe.apply(cv2.cvtColor(image_with_hull, cv2.COLOR_BGR2GRAY))
    
    # 히스토그램 평탄화 적용
    equalized_image = cv2.equalizeHist(enhanced_image)
    
    # Multi-Otsu thresholding 적용
    thresholds = filters.threshold_multiotsu(equalized_image, classes=4)
    brightest_region_mask_clahe = (equalized_image > thresholds[-1]).astype(np.uint8)
    
    kernel_dilate = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (20, 20))
    kernel_erode = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (4, 4))
    closed_mask_clahe = cv2.morphologyEx(brightest_region_mask_clahe, cv2.MORPH_ERODE, kernel_erode)
    closed_mask_clahe = cv2.morphologyEx(closed_mask_clahe, cv2.MORPH_DILATE, kernel_dilate)
    closed_mask_clahe = cv2.morphologyEx(closed_mask_clahe, cv2.MORPH_ERODE, kernel_erode)
    
    contour_result_clahe = extract_largest_contour(closed_mask_clahe * 255, image)

    # 라벨을 그리는 부분
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            label_data = json.load(f)
        
        # 예를 들어, 라벨 데이터에서 좌표 가져오기
        if 'annotations' in label_data:
            for annotation in label_data['annotations']:
                if 'points' in annotation:
                    points = np.array(annotation['points'], dtype=np.int32)
                    cv2.polylines(contour_result_clahe, [points], isClosed=True, color=(0, 255, 0), thickness=1)
    
    cv2.imwrite(output_path, contour_result_clahe)

# 각 폴더를 탐색하여 이미지 처리 및 저장
for folder_name in os.listdir(input_dir):
    folder_path = os.path.join(input_dir, folder_name)
    if os.path.isdir(folder_path):
        for image_name in os.listdir(folder_path):
            if image_name.endswith(".png"):
                image_path = os.path.join(folder_path, image_name)
                label_path = os.path.join(label_dir, folder_name, f"{os.path.splitext(image_name)[0]}.json")
                
                hand_side = "right" if "R" in image_name else "left" if "L" in image_name else "unknown"
                
                output_filename = f"{folder_name}_{hand_side}_{image_name}"
                output_path = os.path.join(output_dir, output_filename)
                
                try:
                    process_image(image_path, output_path, label_path)
                    print(f"Processed and saved: {output_path}")
                except Exception as e:
                    print(f"Error processing file: {image_path}")
                    print(str(e))
# Out:
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID521_unknown_image1667177691187.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID521_unknown_image1667177664643.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID038_unknown_image1661318857820.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID038_unknown_image1661318884439.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID008_unknown_image1661145313061.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID008_unknown_image1661145286692.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID034_unknown_image1661317748865.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID034_unknown_image1661317775801.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID327_unknown_image1664846512328.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID327_unknown_image1664846497621.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID345_unknown_image1664932998571.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID345_unknown_image1664932982615.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID313_unknown_image1664241736840.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID313_unknown_image1664241753946.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID122_unknown_image1661909071872.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID122_unknown_image1661908973880.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID070_unknown_image1661736042863.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID070_unknown_image1661736017073.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID384_unknown_image1665536522908.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID384_unknown_image1665536548947.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID340_unknown_image1664932097820.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID340_unknown_image1664932078191.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID381_unknown_image1665453788164.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID381_unknown_image1665453804998.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID026_unknown_image1661305088598.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID026_unknown_image1661305115919.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID014_unknown_image1661216907060.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID014_unknown_image1661216876670.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID387_unknown_image1665536734529.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID387_unknown_image1665536751182.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID491_unknown_image1666662529733.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID491_unknown_image1666662514536.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID386_unknown_image1665536682762.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID386_unknown_image1665536667575.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID131_unknown_image1662339776115.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID131_unknown_image1662339793561.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID497_unknown_image1666746276816.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID497_unknown_image1666746303659.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID091_unknown_image1661821945630.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID091_unknown_image1661821925422.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID532_unknown_image1667265082425.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID532_unknown_image1667265108478.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID474_unknown_image1666660464317.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID474_unknown_image1666660496521.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID426_unknown_image1666059514671.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID426_unknown_image1666059499748.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID114_unknown_image1661908066059.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID114_unknown_image1661908082014.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID094_unknown_image1661822143988.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID094_unknown_image1661822172047.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID548_unknown_image1667354167046.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID548_unknown_image1667354140846.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID329_unknown_image1664846908144.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID329_unknown_image1664846927035.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID390_unknown_image1665536934428.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID390_unknown_image1665536917342.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID072_unknown_image1661736317458.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID072_unknown_image1661736289639.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID304_unknown_image1664241185947.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID304_unknown_image1664241204728.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID064_unknown_image1661734980185.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID064_unknown_image1661735006875.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID073_unknown_image1661736410568.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID073_unknown_image1661736368856.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID338_unknown_image1664848616528.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID338_unknown_image1664848589440.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID419_unknown_image1666055871574.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID419_unknown_image1666055889713.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID420_unknown_image1666055946544.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID420_unknown_image1666055919663.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID467_unknown_image1666659745388.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID467_unknown_image1666659761339.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID359_unknown_image1664934986606.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID359_unknown_image1664935001598.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID024_unknown_image1661304319731.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID024_unknown_image1661304293036.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID537_unknown_image1667265875051.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID537_unknown_image1667265888689.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID455_unknown_image1666573897114.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID455_unknown_image1666573923456.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID005_unknown_image1661144852117.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID005_unknown_image1661144825412.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID403_unknown_image1665539962902.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/
png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID458_unknown_image1666575044555.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID276_unknown_image1664155004523.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID276_unknown_image1664154988975.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID424_unknown_image1666059342311.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID424_unknown_image1666059321587.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID395_unknown_image1665538654390.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID395_unknown_image1665538625965.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID506_unknown_image1666747111320.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID506_unknown_image1666747096906.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID488_unknown_image1666662075807.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID488_unknown_image1666662049185.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID050_unknown_image1661389664418.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID050_unknown_image1661389690781.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID096_unknown_image1661823153715.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID096_unknown_image1661823124435.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID408_unknown_image1665540854846.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID408_unknown_image1665540873549.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID351_unknown_image1664933934603.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID351_unknown_image1664933949941.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID442_unknown_image1666142965935.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID442_unknown_image1666142946835.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID504_unknown_image1666746881112.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID504_unknown_image1666746900634.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID339_unknown_image1664931867611.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID339_unknown_image1664931829104.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID010_unknown_image1661145591320.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID010_unknown_image1661145563354.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID397_unknown_image1665538903963.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID397_unknown_image1665538920029.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID353_unknown_image1664934044092.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID353_unknown_image1664934060702.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID319_unknown_image1664243649839.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID319_unknown_image1664243678195.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID457_unknown_image1666574567789.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID457_unknown_image1666574582888.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID526_unknown_image1667179311111.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID526_unknown_image1667179338069.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID100_unknown_image1661823638297.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID100_unknown_image1661823665932.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID322_unknown_image1664845420262.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID322_unknown_image1664845446087.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID083_unknown_image1661737706000.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID083_unknown_image1661737667056.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID039_unknown_image1661318938038.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID039_unknown_image1661318964936.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID492_unknown_image1666662593757.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID492_unknown_image1666662609806.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID323_unknown_image1664846188621.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID323_unknown_image1664846204441.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID437_unknown_image1666060713139.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID437_unknown_image1666060743242.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID448_unknown_image1666573462779.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID448_unknown_image1666573448004.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID503_unknown_image1666746789169.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID503_unknown_image1666746807797.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID071_unknown_image1661736107465.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID071_unknown_image1661736133844.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID382_unknown_image1665453897981.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID382_unknown_image1665453880555.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID055_unknown_image1661391560138.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID055_unknown_image1661391587575.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID341_unknown_image1664932140936.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID341_unknown_image1664932155633.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID427_unknown_image1666059630733.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID427_unknown_image1666059605746.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID501_unknown_image1666746629213.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID501_unknown_image1666746602578.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID312_unknown_image1664241697980.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID312_unknown_image1664241670872.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID087_unknown_image1661821482292.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID087_unknown_image1661821466164.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID124_unknown_image1661910096458.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing/ID124_unknown_image1661910068358.png

# %%
from PIL import Image

# 이미지 경로
image_path = "/data/ephemeral/home/MCG/data/groupKFold_seed21/fold1/train/Image/image1661144206667.png"

# 저장 경로
original_save_path = "original_image_2048x2048.png"
resized_save_path = "resized_image_512x512.png"

# 이미지 로드
original_image = Image.open(image_path)

# 원본 이미지 저장
original_image.save(original_save_path)
print(f"Original image saved at {original_save_path}")

# 512x512로 리사이즈
resized_image = original_image.resize((512, 512))

# 리사이즈된 이미지 저장
resized_image.save(resized_save_path)
print(f"Resized image saved at {resized_save_path}")
# Out:
# Original image saved at original_image_2048x2048.png
# Resized image saved at resized_image_512x512.png
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
