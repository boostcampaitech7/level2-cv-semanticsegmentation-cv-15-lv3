# %%
import os
import cv2
import numpy as np
import json
from skimage import filters
from scipy import ndimage

# 입력 및 출력 디렉토리 설정
input_dir = "/data/ephemeral/home/MCG/data/train/DCM"
output_dir = "/data/ephemeral/home/MCG/preProcessing2"
label_dir = "/data/ephemeral/home/MCG/data/train/outputs_json"  # 라벨이 있는 디렉토리 경로 설정
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 가장 큰 외곽선 추출 함수
def extract_largest_contour(result_mask, original_image):
    contours, _ = cv2.findContours(result_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        contour_mask = np.zeros_like(result_mask)
        cv2.drawContours(contour_mask, [largest_contour], -1, 255, thickness=cv2.FILLED)
        return cv2.bitwise_and(original_image, original_image, mask=contour_mask)
    return result_mask

# 각 이미지를 처리하여 CLAHE 후 가장 큰 컨투어 추출 결과 저장
def process_image(image_path, output_path, label_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    _, binary = cv2.threshold(gray_image, 45, 255, cv2.THRESH_BINARY)
    kernel = np.ones((8, 8), np.uint8)
    binary = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
    
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    largest_contour = max(contours, key=cv2.contourArea)
    hull = cv2.convexHull(largest_contour)
    
    convex_hull_mask = np.zeros_like(gray_image)
    cv2.drawContours(convex_hull_mask, [hull], -1, 255, thickness=cv2.FILLED)
    image_with_hull = cv2.bitwise_and(image, image, mask=convex_hull_mask)
    
    clahe = cv2.createCLAHE(clipLimit=8, tileGridSize=(33, 33))
    enhanced_image = clahe.apply(cv2.cvtColor(image_with_hull, cv2.COLOR_BGR2GRAY))
    
    # 히스토그램 평탄화 적용
    equalized_image = cv2.equalizeHist(enhanced_image)
    
    # Multi-Otsu thresholding 적용
    thresholds = filters.threshold_multiotsu(equalized_image, classes=4)
    brightest_region_mask_clahe = (equalized_image > thresholds[-1]).astype(np.uint8)
    
    kernel_dilate = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (20, 20))
    kernel_erode = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (4, 4))
    closed_mask_clahe = cv2.morphologyEx(brightest_region_mask_clahe, cv2.MORPH_ERODE, kernel_erode)
    closed_mask_clahe = cv2.morphologyEx(closed_mask_clahe, cv2.MORPH_DILATE, kernel_dilate)
    closed_mask_clahe = cv2.morphologyEx(closed_mask_clahe, cv2.MORPH_ERODE, kernel_erode)
    
    contour_result_clahe = extract_largest_contour(closed_mask_clahe * 255, image)
    #contour_result_clahe=cv2.bitwise_and(image, image, mask=closed_mask_clahe)

    # 라벨을 그리는 부분
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            label_data = json.load(f)
        
        # 예를 들어, 라벨 데이터에서 좌표 가져오기
        if 'annotations' in label_data:
            for annotation in label_data['annotations']:
                if 'points' in annotation:
                    points = np.array(annotation['points'], dtype=np.int32)
                    cv2.polylines(contour_result_clahe, [points], isClosed=True, color=(0, 255, 0), thickness=1)
    
    cv2.imwrite(output_path, contour_result_clahe)

# 각 폴더를 탐색하여 이미지 처리 및 저장
for folder_name in os.listdir(input_dir):
    folder_path = os.path.join(input_dir, folder_name)
    if os.path.isdir(folder_path):
        for image_name in os.listdir(folder_path):
            if image_name.endswith(".png"):
                image_path = os.path.join(folder_path, image_name)
                label_path = os.path.join(label_dir, folder_name, f"{os.path.splitext(image_name)[0]}.json")
                
                hand_side = "right" if "R" in image_name else "left" if "L" in image_name else "unknown"
                
                output_filename = f"{folder_name}_{hand_side}_{image_name}"
                output_path = os.path.join(output_dir, output_filename)
                
                try:
                    process_image(image_path, output_path, label_path)
                    print(f"Processed and saved: {output_path}")
                except Exception as e:
                    print(f"Error processing file: {image_path}")
                    print(str(e))
# Out:
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID521_unknown_image1667177691187.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID521_unknown_image1667177664643.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID038_unknown_image1661318857820.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID038_unknown_image1661318884439.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID008_unknown_image1661145313061.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID008_unknown_image1661145286692.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID034_unknown_image1661317748865.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID034_unknown_image1661317775801.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID327_unknown_image1664846512328.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID327_unknown_image1664846497621.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID345_unknown_image1664932998571.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID345_unknown_image1664932982615.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID313_unknown_image1664241736840.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID313_unknown_image1664241753946.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID122_unknown_image1661909071872.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID122_unknown_image1661908973880.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID070_unknown_image1661736042863.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID070_unknown_image1661736017073.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID384_unknown_image1665536522908.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID384_unknown_image1665536548947.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID340_unknown_image1664932097820.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID340_unknown_image1664932078191.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID381_unknown_image1665453788164.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID381_unknown_image1665453804998.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID026_unknown_image1661305088598.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID026_unknown_image1661305115919.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID014_unknown_image1661216907060.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID014_unknown_image1661216876670.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID387_unknown_image1665536734529.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID387_unknown_image1665536751182.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID491_unknown_image1666662529733.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID491_unknown_image1666662514536.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID386_unknown_image1665536682762.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID386_unknown_image1665536667575.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID131_unknown_image1662339776115.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID131_unknown_image1662339793561.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID497_unknown_image1666746276816.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID497_unknown_image1666746303659.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID091_unknown_image1661821945630.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID091_unknown_image1661821925422.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID532_unknown_image1667265082425.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID532_unknown_image1667265108478.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID474_unknown_image1666660464317.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID474_unknown_image1666660496521.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID426_unknown_image1666059514671.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID426_unknown_image1666059499748.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID114_unknown_image1661908066059.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID114_unknown_image1661908082014.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID094_unknown_image1661822143988.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID094_unknown_image1661822172047.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID548_unknown_image1667354167046.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID548_unknown_image1667354140846.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID329_unknown_image1664846908144.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID329_unknown_image1664846927035.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID390_unknown_image1665536934428.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID390_unknown_image1665536917342.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID072_unknown_image1661736317458.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID072_unknown_image1661736289639.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID304_unknown_image1664241185947.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID304_unknown_image1664241204728.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID064_unknown_image1661734980185.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID064_unknown_image1661735006875.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID073_unknown_image1661736410568.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID073_unknown_image1661736368856.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID338_unknown_image1664848616528.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID338_unknown_image1664848589440.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID419_unknown_image1666055871574.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID419_unknown_image1666055889713.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID420_unknown_image1666055946544.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID420_unknown_image1666055919663.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID467_unknown_image1666659745388.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID467_unknown_image1666659761339.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID359_unknown_image1664934986606.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID359_unknown_image1664935001598.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID024_unknown_image1661304319731.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID024_unknown_image1661304293036.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID537_unknown_image1667265875051.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID537_unknown_image1667265888689.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID455_unknown_image1666573897114.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID455_unknown_image1666573923456.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID005_unknown_image1661144852117.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID005_unknown_image1661144825412.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID403_unknown_image1665539962902.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID403_unknown_image1665539937219.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID113_unknown_image1661907993946.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID113_unknown_image1661908013121.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID483_unknown_image1666661359745.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID483_unknown_image1666661332742.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID117_unknown_image1661908355715.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID117_unknown_image1661908331939.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID499_unknown_image1666746427808.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID499_unknown_image1666746454260.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID374_unknown_image1665452614591.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID374_unknown_image1665452630511.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID462_unknown_image1666575444051.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID462_unknown_image1666575470608.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID411_unknown_image1666054819179.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID411_unknown_image1666054793047.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID459_unknown_image1666575127804.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID459_unknown_image1666575109683.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID119_unknown_image1661908653923.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID119_unknown_image1661908672926.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID278_unknown_image1664155340191.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID278_unknown_image1664155311840.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID436_unknown_image1666060373215.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID436_unknown_image1666060344877.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID396_unknown_image1665538845008.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID396_unknown_image1665538862153.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID294_unknown_image1664157399991.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID294_unknown_image1664157383539.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID505_unknown_image1666746978974.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID505_unknown_image1666747005566.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID471_unknown_image1666660194187.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID471_unknown_image1666660164224.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID451_unknown_image1666573636491.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID451_unknown_image1666573621389.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID511_unknown_image1666748000469.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID511_unknown_image1666747984726.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID429_unknown_image1666059811309.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID429_unknown_image1666059783189.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID496_unknown_image1666746206399.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID496_unknown_image1666746224080.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID524_unknown_image1667178816657.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID524_unknown_image1667178833635.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID018_unknown_image1661218865003.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID018_unknown_image1661218881444.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID431_unknown_image1666059976090.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID431_unknown_image1666059948563.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID311_unknown_image1664241612376.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID311_unknown_image1664241629103.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID007_unknown_image1661145193855.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID007_unknown_image1661145229731.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID350_unknown_image1664933852344.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID350_unknown_image1664933867937.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID498_unknown_image1666746347755.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID498_unknown_image1666746376659.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID432_unknown_image1666060029154.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID432_unknown_image1666060046127.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID093_unknown_image1661822091755.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID093_unknown_image1661822075331.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID051_unknown_image1661390117495.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID051_unknown_image1661390147363.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID056_unknown_image1661391716556.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID056_unknown_image1661391665806.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID412_unknown_image1666054868738.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID412_unknown_image1666054886283.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID414_unknown_image1666055056393.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID414_unknown_image1666055073787.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID303_unknown_image1664241119204.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID303_unknown_image1664241147172.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID062_unknown_image1661393737086.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID062_unknown_image1661393720347.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID110_unknown_image1661907717648.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID110_unknown_image1661907733328.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID400_unknown_image1665539259135.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID400_unknown_image1665539233052.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID514_unknown_image1666748254136.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID514_unknown_image1666748279898.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID461_unknown_image1666575389787.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID461_unknown_image1666575371827.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID367_unknown_image1665450035770.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID367_unknown_image1665450051887.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID363_unknown_image1664935989808.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID363_unknown_image1664935962797.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID450_unknown_image1666573567716.png
# Processed and saved: /data/ephemeral/home/MCG/preProcessing2/ID450_unknown_image1666573582796.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 90
#      87 output_path = os.path.join(output_dir, output_filename)
#      89 try:
# ---> 90     process_image(image_path, output_path, label_path)
#      91     print(f"Processed and saved: {output_path}")
#      92 except Exception as e:
#
# Cell In[15], line 38, in process_image(image_path, output_path, label_path)
#      35 largest_contour = max(contours, key=cv2.contourArea)
#      36 hull = cv2.convexHull(largest_contour)
# ---> 38 convex_hull_mask = np.zeros_like(gray_image)
#      39 cv2.drawContours(convex_hull_mask, [hull], -1, 255, thickness=cv2.FILLED)
#      40 image_with_hull = cv2.bitwise_and(image, image, mask=convex_hull_mask)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/core/numeric.py:132, in zeros_like(a, dtype, order, subok, shape)
#     130 # needed instead of a 0 to get same result as zeros for string dtypes
#     131 z = zeros(1, dtype=res.dtype)
# --> 132 multiarray.copyto(res, z, casting='unsafe')
#     133 return res
#
# KeyboardInterrupt:

# %%
import os
import json
import cv2
import numpy as np

# Define directories
label_dir = "/data/ephemeral/home/MCG/data/train/outputs_json"
input_dir = "/data/ephemeral/home/MCG/data/train/DCM"
output_dir = "/data/ephemeral/home/MCG/data/annotated_images"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Colors for each class
COLORS = {
    "finger": (255, 0, 0),  # Blue
    "radius_ulna": (0, 255, 0),  # Green
    "others": (0, 0, 255)  # Red
}

# Draw polygons, labels, and arrows on the image
def draw_polygons_with_arrows(image, annotations):
    for annotation in annotations:
        label = annotation['label']
        points = np.array(annotation['points'], dtype=np.int32).reshape((-1, 1, 2))
        color = COLORS.get("others", (255, 255, 255))  # Default to white if label not found

        # Assign color based on label
        if 'finger' in label.lower():
            color = COLORS['finger']
        elif label in ['Radius', 'Ulna']:
            color = COLORS['radius_ulna']
        
        # Draw polygon
        cv2.polylines(image, [points], isClosed=True, color=color, thickness=2)

        # Calculate the centroid of the polygon
        moments = cv2.moments(points)
        if moments["m00"] != 0:
            cx = int(moments["m10"] / moments["m00"])
            cy = int(moments["m01"] / moments["m00"])
        else:
            cx, cy = points[0][0]  # Fallback to the first point if area is zero

        # Determine text position slightly offset from the polygon
        text_position = (cx + 10, cy - 10)  # Offset text for better visibility

        # Draw arrow from text to centroid
        cv2.arrowedLine(image, text_position, (cx, cy), color, thickness=1, tipLength=0.2)

        # Add text label at the offset position
        cv2.putText(image, label, text_position, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), thickness=1, lineType=cv2.LINE_AA)

# Process each patient's images
for patient_id in os.listdir(label_dir):
    patient_label_path = os.path.join(label_dir, patient_id)
    patient_image_path = os.path.join(input_dir, patient_id)
    
    if not os.path.isdir(patient_label_path):
        continue

    for json_file in os.listdir(patient_label_path):
        if json_file.endswith(".json"):
            # Load JSON data
            json_path = os.path.join(patient_label_path, json_file)
            with open(json_path, "r") as f:
                data = json.load(f)

            # Prepare image path and output path
            image_name = json_file.replace(".json", ".png")
            image_path = os.path.join(patient_image_path, image_name)
            output_path = os.path.join(output_dir, f"{patient_id}_{image_name}")
            
            # Skip if the corresponding image does not exist
            if not os.path.isfile(image_path):
                continue

            # Read the image using OpenCV
            image = cv2.imread(image_path)
            if image is None:
                continue

            # Draw polygons, labels, and arrows on the image
            draw_polygons_with_arrows(image, data['annotations'])

            # Save the annotated image
            cv2.imwrite(output_path, image)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 87
#      84 draw_polygons_with_arrows(image, data['annotations'])
#      86 # Save the annotated image
# ---> 87 cv2.imwrite(output_path, image)
#
# KeyboardInterrupt:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
from PIL import Image

# 이미지 경로
image_path = "/data/ephemeral/home/MCG/data/groupKFold_seed21/fold1/train/Image/image1661144206667.png"

# 저장 경로
original_save_path = "original_image_2048x2048.png"
resized_save_path = "resized_image_512x512.png"

# 이미지 로드
original_image = Image.open(image_path)

# 원본 이미지 저장
original_image.save(original_save_path)
print(f"Original image saved at {original_save_path}")

# 512x512로 리사이즈
resized_image = original_image.resize((512, 512))

# 리사이즈된 이미지 저장
resized_image.save(resized_save_path)
print(f"Resized image saved at {resized_save_path}")
# Out:
# Original image saved at original_image_2048x2048.png
# Resized image saved at resized_image_512x512.png
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
